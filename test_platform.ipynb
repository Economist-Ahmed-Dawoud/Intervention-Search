# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import warnings
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)

# Configure plotting
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# Import HT and Intervention Search
from ht_categ import HT, HTConfig
from intervention_search import (
    InterventionSearch,
    DOOperator,
    verify_do_operator_properties,
    TimeSeriesInterventionAnalyzer,
    create_intervention_report
)

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %%
# Load retail store data
df = pd.read_csv('test_profitops.csv')
df.head()
# Out:
#    Price  CompetitorPriceIndex  SellThrough  StoreSales  StoreTraffic  \
# 0  53.97                  0.92         8.62      197.56        974.07
# 1  41.83                  0.77         9.31      147.74        888.37
# 2  63.47                  0.91         4.35      112.78       1138.87
# 3  48.62                  1.17         8.74      270.38        914.02
# 4  51.87                  0.89        -1.28       20.49       1007.51
#
#    DemandPotential  InventoryAvailability  StockLevel  PromoFlag  \
# 0             6.60                   0.88       73.39          0
# 1             8.53                   0.93      123.55          0
# 2             2.28                   1.00      132.05          0
# 3             7.44                   0.81      110.33          0
# 4             2.50                   1.00       79.55          1
#
#    CompetitorPromoFlag  CompetitorStockPresence                      Week  \
# 0                    0                        0  2023-03-20T00:00:00.000Z
# 1                    0                        1  2023-03-20T00:00:00.000Z
# 2                    0                        1  2023-03-20T00:00:00.000Z
# 3                    0                        0  2023-03-20T00:00:00.000Z
# 4                    1                        1  2023-03-20T00:00:00.000Z
#
#       SKU Region
# 0   SKU_1   West
# 1  SKU_10  South
# 2  SKU_11   West
# 3  SKU_12  South
# 4  SKU_13   East

# %%
df['Week'] = pd.to_datetime(df['Week'])
df['Week_Num'] = df['Week'].dt.isocalendar().week
df['Week_Sin'] = np.sin(2 * np.pi * df['Week_Num']/52)
df['Week_Cos'] = np.cos(2 * np.pi * df['Week_Num']/52)
df['Region_Code'] = df['Region'].astype('category').cat.codes
df['SKU_Code'] = df['SKU'].astype('category').cat.codes

# %%
# Updated Nodes List (No changes to names)
nodes = [
    "SKU_Code", "Region_Code", "Week_Sin", "Week_Cos", 
    "Price", "StockLevel", "DemandPotential", "PromoFlag", 
    "StoreTraffic", "InventoryAvailability", 
    "CompetitorPriceIndex", "CompetitorPromoFlag", "CompetitorStockPresence", 
    "StoreSales", "SellThrough"
]

# Updated Edges List (Optimized based on AutoML)
edges = [
    # --- Hierarchical Drivers ---
    ("SKU_Code", "Price"),
    ("SKU_Code", "StockLevel"),
    ("SKU_Code", "DemandPotential"),
    ("SKU_Code", "PromoFlag"),
    
    ("Region_Code", "DemandPotential"),
    ("Region_Code", "StoreTraffic"),
    ("Region_Code", "StockLevel"),
    ("Region_Code", "PromoFlag"),
    # REMOVED: Region -> Competitor Nodes (R² was 0.0, meaning no causality found)

    # --- Temporal/Seasonality Drivers ---
    # Added Week -> Price to improve the low R² (0.35)
    ("Week_Sin", "Price"),
    ("Week_Cos", "Price"),
    ("Week_Sin", "DemandPotential"),
    ("Week_Cos", "DemandPotential"),
    ("Week_Sin", "StoreTraffic"),
    ("Week_Cos", "StoreTraffic"),

    # --- Inventory Logic ---
    ("DemandPotential", "StockLevel"),
    ("StockLevel", "InventoryAvailability"),
    ("StockLevel", "PromoFlag"),

    # --- Competitor Dynamics (Exogenous Impact) ---
    # Competitors are now Roots (Inputs), influencing us, but not influenced by us
    ("CompetitorPriceIndex", "Price"),
    ("CompetitorPriceIndex", "StoreTraffic"),
    ("CompetitorPriceIndex", "StoreSales"),
    
    ("CompetitorPromoFlag", "PromoFlag"),
    ("CompetitorPromoFlag", "StoreTraffic"),
    ("CompetitorPromoFlag", "StoreSales"),
    
    ("CompetitorStockPresence", "StoreSales"),

    # --- The Sales Funnel (High Confidence Section) ---
    ("PromoFlag", "StoreTraffic"),
    ("PromoFlag", "StoreSales"),
    ("StoreTraffic", "StoreSales"),
    ("InventoryAvailability", "StoreSales"),
    ("Price", "StoreSales"),

    # --- Outcomes ---
    ("StoreSales", "SellThrough"),
    ("StockLevel", "SellThrough")
]

# %%
adj_matrix = pd.DataFrame(0, index=nodes, columns=nodes)
for parent, child in edges:
    adj_matrix.loc[parent, child] = 1

# %%
# Verify it's a valid DAG
G = nx.from_pandas_adjacency(adj_matrix, create_using=nx.DiGraph())
assert nx.is_directed_acyclic_graph(G), "❌ Graph contains cycles!"
print("   • DAG structure: Valid ✓")
# Out:
#    • DAG structure: Valid ✓

# %%
df[nodes].head()
# Out:
#    SKU_Code  Region_Code  Week_Sin  Week_Cos  Price  StockLevel  \
# 0         0            3  0.992709  0.120537  53.97       73.39
# 1         1            2  0.992709  0.120537  41.83      123.55
# 2         2            3  0.992709  0.120537  63.47      132.05
# 3         3            2  0.992709  0.120537  48.62      110.33
# 4         4            0  0.992709  0.120537  51.87       79.55
#
#    DemandPotential  PromoFlag  StoreTraffic  InventoryAvailability  \
# 0             6.60          0        974.07                   0.88
# 1             8.53          0        888.37                   0.93
# 2             2.28          0       1138.87                   1.00
# 3             7.44          0        914.02                   0.81
# 4             2.50          1       1007.51                   1.00
#
#    CompetitorPriceIndex  CompetitorPromoFlag  CompetitorStockPresence  \
# 0                  0.92                    0                        0
# 1                  0.77                    0                        1
# 2                  0.91                    0                        1
# 3                  1.17                    0                        0
# 4                  0.89                    1                        1
#
#    StoreSales  SellThrough
# 0      197.56         8.62
# 1      147.74         9.31
# 2      112.78         4.35
# 3      270.38         8.74
# 4       20.49        -1.28

# %%
config = HTConfig(
    graph=adj_matrix,
    model_type='AutoML',  # Enables automatic model selection
    auto_ml=True,
    auto_ml_models=['LinearRegression', 'RandomForest', 'Xgboost', 'LightGBM'],
    aggregator='max',
    root_cause_top_k=3)

# Create and train model
print("🎯 Training causal model with AutoML...\n")
ht_model = HT(config)
ht_model.train(df, perform_cv=True, verbose_automl=True)
# Out:
# 🎯 Training causal model with AutoML...
#
# ============================================================
# 🎓 TRAINING MODELS WITH QUALITY ASSESSMENT
# ============================================================
#
# 📊 Detecting variable types...
#    ✓ SKU_Code: CONTINUOUS
#    ✓ Region_Code: CATEGORICAL (4 classes: [np.int8(0), np.int8(1), np.int8(2), np.int8(3)]...)
#    ✓ Week_Sin: CONTINUOUS
#    ✓ Week_Cos: CONTINUOUS
#    ✓ Price: CONTINUOUS
#    ✓ StockLevel: CONTINUOUS
#    ✓ DemandPotential: CONTINUOUS
#    ✓ PromoFlag: CATEGORICAL (2 classes: [np.int64(0), np.int64(1)]...)
#    ✓ StoreTraffic: CONTINUOUS
#    ✓ InventoryAvailability: CONTINUOUS
#    ✓ CompetitorPriceIndex: CONTINUOUS
#    ✓ CompetitorPromoFlag: CATEGORICAL (2 classes: [np.int64(0), np.int64(1)]...)
#    ✓ CompetitorStockPresence: CATEGORICAL (2 classes: [np.int64(0), np.int64(1)]...)
#    ✓ StoreSales: CONTINUOUS
#    ✓ SellThrough: CONTINUOUS
#
# 🤖 Training models (AUTO-ML mode: 4 models per node)...
#    ✓ SKU_Code: Root node (no parents) - baseline scaling only
#    ✓ Region_Code: Root node (no parents) - baseline scaling only
#    ✓ Week_Sin: Root node (no parents) - baseline scaling only
#    ✓ Week_Cos: Root node (no parents) - baseline scaling only
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000379 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 199
# [LightGBM] [Info] Number of data points in the train set: 5200, number of used features: 4
# [LightGBM] [Info] Start training from score 50.041977
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000108 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 50.079308
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 198
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 50.066752
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000087 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 197
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 50.049627
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 197
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 50.053957
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 49.960240
#    ✓ Price: AUTO-ML → RandomForest | R²: 0.830 | RMSE: 3.281
#       Tested models:
#         - LinearRegression: R²: 0.001, RMSE: 7.957
#         - RandomForest: R²: 0.830, RMSE: 3.281
#         - Xgboost: R²: 0.548, RMSE: 5.355
#         - LightGBM: R²: 0.214, RMSE: 7.058
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000051 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 309
# [LightGBM] [Info] Number of data points in the train set: 5200, number of used features: 3
# [LightGBM] [Info] Start training from score 100.173517
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 309
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 3
# [LightGBM] [Info] Start training from score 100.122471
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 309
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 3
# [LightGBM] [Info] Start training from score 100.274096
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000131 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 309
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 3
# [LightGBM] [Info] Start training from score 99.872442
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000139 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 309
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 3
# [LightGBM] [Info] Start training from score 100.329065
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000163 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 309
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 3
# [LightGBM] [Info] Start training from score 100.269512
#    ✓ StockLevel: AUTO-ML → RandomForest | R²: 0.831 | RMSE: 8.233
#       Tested models:
#         - LinearRegression: R²: 0.000, RMSE: 20.027
#         - RandomForest: R²: 0.831, RMSE: 8.233
#         - Xgboost: R²: 0.512, RMSE: 13.991
#         - LightGBM: R²: 0.175, RMSE: 18.196
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 138
# [LightGBM] [Info] Number of data points in the train set: 5200, number of used features: 4
# [LightGBM] [Info] Start training from score 5.799215
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 138
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 5.782260
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 138
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 5.798373
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 138
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 5.785255
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 138
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 5.791599
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 138
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 4
# [LightGBM] [Info] Start training from score 5.838591
#    ✓ DemandPotential: AUTO-ML → RandomForest | R²: 0.746 | RMSE: 1.606
#       Tested models:
#         - LinearRegression: R²: 0.002, RMSE: 3.182
#         - RandomForest: R²: 0.746, RMSE: 1.606
#         - Xgboost: R²: 0.469, RMSE: 2.322
#         - LightGBM: R²: 0.174, RMSE: 2.895
#    ✓ PromoFlag: AUTO-ML → RandomForest | Accuracy: 1.000 | F1: 0.999
#       Tested models:
#         - LinearRegression: Acc: 0.711, F1: 0.000
#         - RandomForest: Acc: 1.000, F1: 0.999
#         - Xgboost: Failed (value 0 for Parameter num_class should be greater )
#         - LightGBM: Acc: 0.748, F1: 0.255
#    ✓ StoreTraffic: AUTO-ML → RandomForest | R²: 0.760 | RMSE: 97.210
#       Tested models:
#         - LinearRegression: R²: 0.001, RMSE: 198.219
#         - RandomForest: R²: 0.760, RMSE: 97.210
#         - Xgboost: R²: 0.471, RMSE: 144.274
#         - LightGBM: R²: 0.192, RMSE: 178.244
#    ✓ InventoryAvailability: AUTO-ML → RandomForest | R²: 0.614 | RMSE: 0.054
#       Tested models:
#         - LinearRegression: R²: 0.000, RMSE: 0.087
#         - RandomForest: R²: 0.614, RMSE: 0.054
#         - Xgboost: R²: 0.053, RMSE: 0.085
#         - LightGBM: R²: 0.051, RMSE: 0.085
#    ✓ CompetitorPriceIndex: Root node (no parents) - baseline scaling only
#    ✓ CompetitorPromoFlag: Root node (no parents) - baseline scaling only
#    ✓ CompetitorStockPresence: Root node (no parents) - baseline scaling only
#    ✓ StoreSales: AUTO-ML → RandomForest | R²: 0.932 | RMSE: 27.548
#       Tested models:
#         - LinearRegression: R²: 0.545, RMSE: 71.108
#         - RandomForest: R²: 0.932, RMSE: 27.548
#         - Xgboost: R²: 0.861, RMSE: 39.391
#         - LightGBM: R²: 0.701, RMSE: 57.668
#    ✓ SellThrough: AUTO-ML → RandomForest | R²: 0.953 | RMSE: 0.942
#       Tested models:
#         - LinearRegression: R²: 0.707, RMSE: 2.340
#         - RandomForest: R²: 0.953, RMSE: 0.942
#         - Xgboost: R²: 0.856, RMSE: 1.641
#         - LightGBM: R²: 0.763, RMSE: 2.105
#
# 📈 Computing baseline statistics...
#
# 🔗 Estimating edge elasticities...
#    ✓ Found 19 edge elasticities
#
# ============================================================
# ✅ TRAINING COMPLETE
# ============================================================
# Total nodes: 15
# Categorical nodes: 4
# Continuous nodes: 11
# Models trained: 8
#
# 💡 Use get_model_quality_report() to see detailed metrics
# ============================================================

# %%
# Model quality report
quality_report = ht_model.get_model_quality_report()

print("\n📊 MODEL QUALITY REPORT")
print("="*70)
print(f"\n🎯 Overall Quality Grade: {quality_report['trust_indicators']['quality_grade']}")
print(f"📈 Graph Coverage: {quality_report['trust_indicators']['graph_coverage']}%")

reg_perf = quality_report['overall_summary']['regression_performance']
print(f"\n📊 Regression Performance:")
print(f"   • Mean R²:   {reg_perf['mean_r2']:.4f}")
print(f"   • Median R²: {reg_perf['median_r2']:.4f}")
print(f"   • Min R²:    {reg_perf['min_r2']:.4f}")
print(f"   • Max R²:    {reg_perf['max_r2']:.4f}")

print("\n" + "="*70)
# Out:
# 📊 MODEL QUALITY REPORT
# ======================================================================
#
# 🎯 Overall Quality Grade: A (Excellent)
# 📈 Graph Coverage: 53.3%
#
# 📊 Regression Performance:
#    • Mean R²:   0.8093
#    • Median R²: 0.8302
#    • Min R²:    0.6138
#    • Max R²:    0.9525
#
# ======================================================================

# %%
# Initialize intervention search
searcher = InterventionSearch(
    graph=ht_model.graph,
    ht_model=ht_model,
    n_simulations=100,  # Monte Carlo samples for uncertainty
    random_seed=42,
    strict_quality_mode=True
)

print("✅ Intervention search initialized")
print(f"   • Monte Carlo simulations: 2000")
print(f"   • Target: +20% sales increase")
# Out:
# ✅ Intervention search initialized
#    • Monte Carlo simulations: 2000
#    • Target: +20% sales increase

# %%
# Run the intervention search
print("\n🔍 Searching for optimal intervention...")

results = searcher.find_interventions(
    target_outcome='StoreSales',
    target_change=20.0,         # +20% increase in sales
    tolerance=3.0,              # Accept ±3% error
    max_intervention_pct=30.0,  # Don't change any node by more than ±30%
    allow_combinations=False,   # Single-node interventions only
    max_candidates=10,          # Return top 10 candidates
    confidence_level=0.90,      # 90% confidence intervals
    verbose=True,
    min_model_quality = 0.7,
    candidate_nodes =['Price', 'StoreTraffic', 'StockLevel'],
    intervention_bounds = {"StockLevel": (5, 25)}  # StockLevel can be changed between 5% and 25%

)
# Out:
# 🔍 Searching for optimal intervention...
#
# ======================================================================
# 🎯 INTERVENTION SEARCH v2.0 (Production Grade)
# ======================================================================
# Target: +20.0% change in StoreSales
# Tolerance: ±3.0% points
# Max intervention: ±30.0%
# Monte Carlo simulations: 100
#
# 📊 Pre-flight checks...
#    Candidate nodes: 3
#    Overall model quality: F
#    ⚠️  1 low-quality models detected
#
# 🔍 Searching 3 candidates...
#    Testing: Price... ✓ -30.0% → +18.2%
#    Testing: StoreTraffic... ✓ +23.3% → +17.1%
#    Testing: StockLevel... ✓ +18.3% → +21.4%
#
# ✅ Validating 3 candidates...
#
# ======================================================================
# ✅ SEARCH COMPLETE
# ======================================================================
#
# Best Intervention:
#    Type: single
#    Variables: StockLevel
#    └─ StockLevel: +18.35%
#
#    Predicted Effect: +21.4% (target: +20.0%)
#    90% Confidence Interval: [-5.5%, +80.1%]
#    50% Confidence Interval: [+0.0%, +29.0%]
#    Confidence Score: 21%
#
#    Status: ✅ APPROVED
#
#    Total Candidates Found: 3
# ======================================================================
